# %%
#Select any one article from your Webhose dataset
import json

#read data from json file
json_data=open("IBM_english.json").readlines()
#print(json_data)

#Output: print the number of articles, titles and publish dates of the first 100 articles.
feeds_read_from_file = []
for line in json_data:
    feeds_read_from_file.append(json.loads(line))
#print(len(feeds_read_from_file))

#Pick a random news article from your Webhose dataset 
article = feeds_read_from_file[9]['text']
article_url = feeds_read_from_file[9]['url']

# %% [markdown]
# # Apply SpaCy to extract subject-verb-object relations from the article

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
SUBJECTS = ["nsubj", "nsubjpass", "csubj", "csubjpass", "agent", "expl"]
OBJECTS = ["dobj", "dative", "attr", "oprd"]

# %%
def getSubsFromConjunctions(subs):
    moreSubs = []
    for sub in subs:
        # rights is a generator
        rights = list(sub.rights)
        rightDeps = {tok.lower_ for tok in rights}
        if "and" in rightDeps:
            moreSubs.extend([tok for tok in rights if tok.dep_ in SUBJECTS or tok.pos_ == "NOUN"])
            if len(moreSubs) > 0:
                moreSubs.extend(getSubsFromConjunctions(moreSubs))
    return moreSubs

# %%
def getObjsFromConjunctions(objs):
    moreObjs = []
    for obj in objs:
        # rights is a generator
        rights = list(obj.rights)
        rightDeps = {tok.lower_ for tok in rights}
        if "and" in rightDeps:
            moreObjs.extend([tok for tok in rights if tok.dep_ in OBJECTS or tok.pos_ == "NOUN"])
            if len(moreObjs) > 0:
                moreObjs.extend(getObjsFromConjunctions(moreObjs))
    return moreObjs

# %%
def getVerbsFromConjunctions(verbs):
    moreVerbs = []
    for verb in verbs:
        rightDeps = {tok.lower_ for tok in verb.rights}
        if "and" in rightDeps:
            moreVerbs.extend([tok for tok in verb.rights if tok.pos_ == "VERB"])
            if len(moreVerbs) > 0:
                moreVerbs.extend(getVerbsFromConjunctions(moreVerbs))
    return moreVerbs

# %%
def findSubs(tok):
    head = tok.head
    while head.pos_ != "VERB" and head.pos_ != "NOUN" and head.head != head:
        head = head.head
    if head.pos_ == "VERB":
        subs = [tok for tok in head.lefts if tok.dep_ == "SUB"]
        if len(subs) > 0:
            verbNegated = isNegated(head)
            subs.extend(getSubsFromConjunctions(subs))
            return subs, verbNegated
        elif head.head != head:
            return findSubs(head)
    elif head.pos_ == "NOUN":
        return [head], isNegated(tok)
    return [], False

# %%
def isNegated(tok):
    negations = {"no", "not", "n't", "never", "none"}
    for dep in list(tok.lefts) + list(tok.rights):
        if dep.lower_ in negations:
            return True
    return False

# %%
def findSVs(tokens):
    svs = []
    verbs = [tok for tok in tokens if tok.pos_ == "VERB"]
    for v in verbs:
        subs, verbNegated = getAllSubs(v)
        if len(subs) > 0:
            for sub in subs:
                svs.append((sub.orth_, "!" + v.orth_ if verbNegated else v.orth_))
    return svs

# %%
def getObjsFromPrepositions(deps):
    objs = []
    for dep in deps:
        if dep.pos_ == "ADP" and dep.dep_ == "prep":
            objs.extend([tok for tok in dep.rights if tok.dep_  in OBJECTS or (tok.pos_ == "PRON" and tok.lower_ == "me")])
    return objs

# %%
def getObjsFromAttrs(deps):
    for dep in deps:
        if dep.pos_ == "NOUN" and dep.dep_ == "attr":
            verbs = [tok for tok in dep.rights if tok.pos_ == "VERB"]
            if len(verbs) > 0:
                for v in verbs:
                    rights = list(v.rights)
                    objs = [tok for tok in rights if tok.dep_ in OBJECTS]
                    objs.extend(getObjsFromPrepositions(rights))
                    if len(objs) > 0:
                        return v, objs
    return None, None

# %%
def getObjFromXComp(deps):
    for dep in deps:
        if dep.pos_ == "VERB" and dep.dep_ == "xcomp":
            v = dep
            rights = list(v.rights)
            objs = [tok for tok in rights if tok.dep_ in OBJECTS]
            objs.extend(getObjsFromPrepositions(rights))
            if len(objs) > 0:
                return v, objs
    return None, None

# %%
def getAllSubs(v):
    verbNegated = isNegated(v)
    subs = [tok for tok in v.lefts if tok.dep_ in SUBJECTS and tok.pos_ != "DET"]
    if len(subs) > 0:
        subs.extend(getSubsFromConjunctions(subs))
    else:
        foundSubs, verbNegated = findSubs(v)
        subs.extend(foundSubs)
    return subs, verbNegated

# %%
def getAllObjs(v):
    # rights is a generator
    rights = list(v.rights)
    objs = [tok for tok in rights if tok.dep_ in OBJECTS]
    objs.extend(getObjsFromPrepositions(rights))

    #potentialNewVerb, potentialNewObjs = getObjsFromAttrs(rights)
    #if potentialNewVerb is not None and potentialNewObjs is not None and len(potentialNewObjs) > 0:
    #    objs.extend(potentialNewObjs)
    #    v = potentialNewVerb

    potentialNewVerb, potentialNewObjs = getObjFromXComp(rights)
    if potentialNewVerb is not None and potentialNewObjs is not None and len(potentialNewObjs) > 0:
        objs.extend(potentialNewObjs)
        v = potentialNewVerb
    if len(objs) > 0:
        objs.extend(getObjsFromConjunctions(objs))
    return v, objs

# %%
def findSVOs(tokens):
    svos = []
    verbs = [tok for tok in tokens if tok.pos_ == "VERB" and tok.dep_ != "aux"]
    for v in verbs:
        subs, verbNegated = getAllSubs(v)
        # hopefully there are subs, if not, don't examine this verb any longer
        if len(subs) > 0:
            v, objs = getAllObjs(v)
            for sub in subs:
                for obj in objs:
                    objNegated = isNegated(obj)
                    svos.append((sub.lower_, "!" + v.lower_ if verbNegated or objNegated else v.lower_, obj.lower_))
    return svos

# %%
def printDeps(toks):
    for tok in toks:
        print(tok.orth_, tok.dep_, tok.pos_, tok.head.orth_, [t.orth_ for t in tok.lefts], [t.orth_ for t in tok.rights])

def testSVOs(sentence):
    #nlp = English()
    tok = nlp(sentence)
    svos = findSVOs(tok)
    printDeps(tok)
    print(svos)
    #svos=svos
    print("--------------------------------------------------")

# %%
from nltk import tokenize
from nltk import word_tokenize, sent_tokenize

# tokenize sentences
#sentences = sent_tokenize(article) 

sentences = sent_tokenize(article)
print('# of sentences:',len(sentences))

SVO=[]
count=0
for sent in sent_tokenize(article):
    print("sentence:",count)
    print(sent)
    testSVOs(sent)
    svos=findSVOs(nlp(sent))
    SVO.append(svos) 
    count=count+1
print(SVO)
# Out:
# # of sentences: 56
# sentence: 0
# Linda Fister's story with IBM beyond mirrors the onset and boom of computers.
# Linda compound PROPN Fister [] []
# Fister poss PROPN story ['Linda'] ["'s"]
# 's case PART Fister [] []
# story nsubj NOUN onset ['Fister'] ['with', 'beyond']
# with prep ADP story [] ['IBM']
# IBM pobj PROPN with [] []
# beyond prep ADP story [] ['mirrors']
# mirrors pobj NOUN beyond [] []
# the det DET onset [] []
# onset ROOT NOUN onset ['story', 'the'] ['and', 'boom', 'of', '.']
# and cc CCONJ onset [] []
# boom conj NOUN onset [] []
# of prep ADP onset [] ['computers']
# computers pobj NOUN of [] []
# . punct PUNCT onset [] []
# []
# --------------------------------------------------
# sentence: 1
# Exeter Township, PA —
# The big metal box with blinking lights transfixed 12-year-old Linda Fister.
# Exeter compound PROPN Township [] []
# Township ROOT PROPN Township ['Exeter'] [',', '—']
# , punct PUNCT Township [] []
# PA compound PROPN — [] []
# — appos PROPN Township ['PA'] ['\n']
#
#   SPACE — [] []
# The det DET box [] []
# big amod ADJ box [] []
# metal compound NOUN box [] []
# box ROOT NOUN box ['The', 'big', 'metal'] ['with', '.']
# with prep ADP box [] ['blinking']
# blinking pcomp VERB with [] ['lights']
# lights dobj NOUN blinking [] ['transfixed']
# transfixed acl VERB lights [] ['Fister']
# 12-year npadvmod ADJ old [] []
# - punct PUNCT old [] []
# old amod ADJ Fister ['12-year', '-'] []
# Linda compound PROPN Fister [] []
# Fister dobj PROPN transfixed ['old', 'Linda'] []
# . punct PUNCT box [] []
# [('box', 'blinking', 'lights'), ('lights', 'transfixed', 'fister')]
# --------------------------------------------------
# sentence: 2
# It was the first computer she had seen, and Fister stood staring in wonder at the state-of-the-art display at the Museum of Science and Industry in Chicago.
# It nsubj PRON was [] []
# was ROOT VERB was ['It'] ['computer', ',', 'and', 'stood']
# the det DET computer [] []
# first amod ADJ computer [] []
# computer attr NOUN was ['the', 'first'] ['seen']
# she nsubj PRON seen [] []
# had aux VERB seen [] []
# seen relcl VERB computer ['she', 'had'] []
# , punct PUNCT was [] []
# and cc CCONJ was [] []
# Fister nsubj PROPN stood [] []
# stood conj VERB was ['Fister'] ['staring', '.']
# staring xcomp VERB stood [] ['in', 'at']
# in prep ADP staring [] ['wonder']
# wonder pobj NOUN in [] []
# at prep ADP staring [] ['display']
# the det DET display [] []
# state nmod NOUN display [] ['-', 'of']
# - punct PUNCT state [] []
# of prep ADP state [] ['-', 'art']
# - punct PUNCT of [] []
# the det DET art [] []
# - punct PUNCT art [] []
# art pobj NOUN of ['the', '-'] []
# display pobj NOUN at ['the', 'state'] ['at']
# at prep ADP display [] ['Museum']
# the det DET Museum [] []
# Museum pobj PROPN at ['the'] ['of', 'in']
# of prep ADP Museum [] ['Science']
# Science pobj PROPN of [] ['and', 'Industry']
# and cc CCONJ Science [] []
# Industry conj PROPN Science [] []
# in prep ADP Museum [] ['Chicago']
# Chicago pobj PROPN in [] []
# . punct PUNCT stood [] []
# [('it', 'was', 'computer')]
# --------------------------------------------------
# sentence: 3
# “It piqued my curiosity,” she said.
# “ ROOT PROPN “ [] []
# It nsubj PRON piqued [] []
# piqued ccomp VERB said ['It'] ['curiosity']
# my poss DET curiosity [] []
# curiosity dobj NOUN piqued ['my'] []
# , punct PUNCT said [] []
# ” punct PUNCT said [] []
# she nsubj PRON said [] []
# said ROOT VERB said ['piqued', ',', '”', 'she'] ['.']
# . punct PUNCT said [] []
# [('it', 'piqued', 'curiosity')]
# --------------------------------------------------
# sentence: 4
# “I thought, 'This is the future.'
# “ ROOT PUNCT “ [] []
# I nsubj PRON thought [] []
# thought ROOT VERB thought ['I'] [',', "'", 'is', '.', "'"]
# , punct PUNCT thought [] []
# ' punct PUNCT thought [] []
# This nsubj DET is [] []
# is ccomp VERB thought ['This'] ['future']
# the det DET future [] []
# future attr NOUN is ['the'] []
# . punct PUNCT thought [] []
# ' punct PUNCT thought [] []
# []
# --------------------------------------------------
# sentence: 5
# ”
# There and then, she decided it would be her future.
# ” ROOT PUNCT ” [] ['\n']
#
#   SPACE ” [] []
# There ROOT ADV There [] []
# and cc CCONJ decided [] []
# then advmod ADV decided [] []
# , punct PUNCT decided [] []
# she nsubj PRON decided [] []
# decided ROOT VERB decided ['and', 'then', ',', 'she'] ['be', '.']
# it nsubj PRON be [] []
# would aux VERB be [] []
# be ccomp VERB decided ['it', 'would'] ['future']
# her poss DET future [] []
# future attr NOUN be ['her'] []
# . punct PUNCT decided [] []
# [('it', 'be', 'future')]
# --------------------------------------------------
# sentence: 6
# A retired computer programmer, Fister, now 75, of Exeter Township was the only woman in her class when she started programming close to 60 years ago.
# A det DET programmer [] []
# retired amod ADJ programmer [] []
# computer compound NOUN programmer [] []
# programmer nsubj NOUN was ['A', 'retired', 'computer'] [',', 'Fister']
# , punct PUNCT programmer [] []
# Fister appos PROPN programmer [] [',', 'now', '75', ',', 'of']
# , punct PUNCT Fister [] []
# now advmod ADV Fister [] []
# 75 appos NUM Fister [] []
# , punct PUNCT Fister [] []
# of prep ADP Fister [] ['Township']
# Exeter compound PROPN Township [] []
# Township pobj PROPN of ['Exeter'] []
# was ROOT VERB was ['programmer'] ['woman', 'started', '.']
# the det DET woman [] []
# only amod ADJ woman [] []
# woman attr NOUN was ['the', 'only'] ['in']
# in prep ADP woman [] ['class']
# her poss DET class [] []
# class pobj NOUN in ['her'] []
# when advmod ADV started [] []
# she nsubj PRON started [] []
# started advcl VERB was ['when', 'she'] ['programming']
# programming xcomp VERB started [] ['ago']
# close quantmod ADV 60 [] []
# to quantmod ADP 60 [] []
# 60 nummod NUM years ['close', 'to'] []
# years npadvmod NOUN ago ['60'] []
# ago advmod ADV programming ['years'] []
# . punct PUNCT was [] []
# [('programmer', 'was', 'woman')]
# --------------------------------------------------
# sentence: 7
# In recognition of Day of the Programmer, an international professional day celebrated Sept. 13, she recently reflected on what it was like to be a woman in the early days of programming.
# In prep ADP reflected [] ['recognition']
# recognition pobj NOUN In [] ['of']
# of prep ADP recognition [] ['Day']
# Day pobj PROPN of [] ['of']
# of prep ADP Day [] ['Programmer']
# the det DET Programmer [] []
# Programmer pobj PROPN of ['the'] [',', 'day']
# , punct PUNCT Programmer [] []
# an det DET day [] []
# international amod ADJ day [] []
# professional amod ADJ day [] []
# day appos NOUN Programmer ['an', 'international', 'professional'] ['celebrated']
# celebrated acl VERB day [] ['Sept.']
# Sept. npadvmod PROPN celebrated [] ['13']
# 13 nummod NUM Sept. [] []
# , punct PUNCT reflected [] []
# she nsubj PRON reflected [] []
# recently advmod ADV reflected [] []
# reflected ROOT VERB reflected ['In', ',', 'she', 'recently'] ['on', '.']
# on prep ADP reflected [] ['was']
# what pobj PRON like [] []
# it nsubj PRON was [] []
# was pcomp VERB on ['it'] ['like', 'be']
# like prep ADJ was ['what'] []
# to aux PART be [] []
# be xcomp VERB was ['to'] ['woman', 'in']
# a det DET woman [] []
# woman attr NOUN be ['a'] []
# in prep ADP be [] ['days']
# the det DET days [] []
# early amod ADJ days [] []
# days pobj NOUN in ['the', 'early'] ['of']
# of prep ADP days [] ['programming']
# programming pobj NOUN of [] []
# . punct PUNCT reflected [] []
# [('it', 'be', 'woman')]
# --------------------------------------------------
# sentence: 8
# A few years after that decisive museum trip, Fister, who grew up in a suburb of the Windy City, walked into the Chicago office of International Business Machines, or IBM, to ask for a job.
# A det DET years [] []
# few amod ADJ years [] []
# years npadvmod NOUN after ['A', 'few'] []
# after prep ADP walked ['years'] ['trip']
# that det DET trip [] []
# decisive amod ADJ trip [] []
# museum compound NOUN trip [] []
# trip pobj NOUN after ['that', 'decisive', 'museum'] []
# , punct PUNCT walked [] []
# Fister nsubj PROPN walked [] [',', 'grew', ',']
# , punct PUNCT Fister [] []
# who nsubj PRON grew [] []
# grew relcl VERB Fister ['who'] ['up', 'in']
# up prt PART grew [] []
# in prep ADP grew [] ['suburb']
# a det DET suburb [] []
# suburb pobj NOUN in ['a'] ['of']
# of prep ADP suburb [] ['City']
# the det DET City [] []
# Windy compound PROPN City [] []
# City pobj PROPN of ['the', 'Windy'] []
# , punct PUNCT Fister [] []
# walked ROOT VERB walked ['after', ',', 'Fister'] ['into', ',', 'ask', '.']
# into prep ADP walked [] ['office']
# the det DET office [] []
# Chicago compound PROPN office [] []
# office pobj NOUN into ['the', 'Chicago'] ['of']
# of prep ADP office [] ['Machines']
# International compound PROPN Machines [] []
# Business compound PROPN Machines [] []
# Machines pobj PROPN of ['International', 'Business'] [',', 'or', 'IBM']
# , punct PUNCT Machines [] []
# or cc CCONJ Machines [] []
# IBM conj PROPN Machines [] []
# , punct PUNCT walked [] []
# to aux PART ask [] []
# ask advcl VERB walked ['to'] ['for']
# for prep ADP ask [] ['job']
# a det DET job [] []
# job pobj NOUN for ['a'] []
# . punct PUNCT walked [] []
# []
# --------------------------------------------------
# sentence: 9
# A precocious teenager, Fister was ushered into the office of a manager.
# A det DET teenager [] []
# precocious amod ADJ teenager [] []
# teenager nsubjpass NOUN ushered ['A', 'precocious'] []
# , punct PUNCT ushered [] []
# Fister nsubjpass PROPN ushered [] []
# was auxpass VERB ushered [] []
# ushered ROOT VERB ushered ['teenager', ',', 'Fister', 'was'] ['into', '.']
# into prep ADP ushered [] ['office']
# the det DET office [] []
# office pobj NOUN into ['the'] ['of']
# of prep ADP office [] ['manager']
# a det DET manager [] []
# manager pobj NOUN of ['a'] []
# . punct PUNCT ushered [] []
# []
# --------------------------------------------------
# sentence: 10
# Impressed by Fister's interest in what were called “business machines,” the man handed her his card and instructed her to return after graduating high school.
# Impressed advcl VERB handed [] ['by']
# by agent ADP Impressed [] ['interest']
# Fister poss PROPN interest [] ["'s"]
# 's case PART Fister [] []
# interest pobj NOUN by ['Fister'] ['in']
# in prep ADP interest [] ['called']
# what nsubjpass PRON called [] []
# were auxpass VERB called [] []
# called pcomp VERB in ['what', 'were'] ['machines']
# “ compound ADJ machines [] []
# business compound NOUN machines [] []
# machines oprd NOUN called ['“', 'business'] []
# , punct PUNCT handed [] []
# ” punct PUNCT handed [] []
# the det DET man [] []
# man nsubj NOUN handed ['the'] []
# handed ROOT VERB handed ['Impressed', ',', '”', 'man'] ['her', 'card', 'and', 'instructed', '.']
# her dobj PRON handed [] []
# his poss DET card [] []
# card dobj NOUN handed ['his'] []
# and cc CCONJ handed [] []
# instructed conj VERB handed [] ['her', 'return']
# her dobj PRON instructed [] []
# to aux PART return [] []
# return xcomp VERB instructed ['to'] ['after']
# after prep ADP return [] ['graduating']
# graduating pcomp VERB after [] ['school']
# high amod ADJ school [] []
# school dobj NOUN graduating ['high'] []
# . punct PUNCT handed [] []
# [('what', 'called', 'machines'), ('man', 'handed', 'her'), ('man', 'handed', 'card')]
# --------------------------------------------------
# sentence: 11
# She did and landed an internship with IBM.
# She nsubj PRON did [] []
# did ROOT VERB did ['She'] ['and', 'landed', '.']
# and cc CCONJ did [] []
# landed conj VERB did [] ['internship']
# an det DET internship [] []
# internship dobj NOUN landed ['an'] ['with']
# with prep ADP internship [] ['IBM']
# IBM pobj PROPN with [] []
# . punct PUNCT did [] []
# []
# --------------------------------------------------
# sentence: 12
# In exchange for her work, Fister received training as a keypuncher, punching holes into the stiff paper cards that issued commands when fed into the large mainframe computers.
# In prep ADP received [] ['exchange']
# exchange pobj NOUN In [] ['for']
# for prep ADP exchange [] ['work']
# her poss DET work [] []
# work pobj NOUN for ['her'] []
# , punct PUNCT received [] []
# Fister nsubj PROPN received [] []
# received ROOT VERB received ['In', ',', 'Fister'] ['training', 'as', ',', 'punching', '.']
# training dobj NOUN received [] []
# as prep ADP received [] ['keypuncher']
# a det DET keypuncher [] []
# keypuncher pobj ADV as ['a'] []
# , punct PUNCT received [] []
# punching advcl VERB received [] ['holes', 'into']
# holes dobj NOUN punching [] []
# into prep ADP punching [] ['cards']
# the det DET cards [] []
# stiff amod ADJ cards [] []
# paper compound NOUN cards [] []
# cards pobj NOUN into ['the', 'stiff', 'paper'] ['issued']
# that nsubj DET issued [] []
# issued relcl VERB cards ['that'] ['commands', 'fed']
# commands dobj NOUN issued [] []
# when advmod ADV fed [] []
# fed advcl VERB issued ['when'] ['into']
# into prep ADP fed [] ['computers']
# the det DET computers [] []
# large amod ADJ computers [] []
# mainframe compound NOUN computers [] []
# computers pobj NOUN into ['the', 'large', 'mainframe'] []
# . punct PUNCT received [] []
# [('fister', 'received', 'training'), ('cards', 'issued', 'commands')]
# --------------------------------------------------
# sentence: 13
# She also learned the jobs of card sorting and board wiring, all of which were considered women's work, she said.
# She nsubj PRON learned [] []
# also advmod ADV learned [] []
# learned ccomp VERB said ['She', 'also'] ['jobs']
# the det DET jobs [] []
# jobs dobj NOUN learned ['the'] ['of', ',', 'considered']
# of prep ADP jobs [] ['sorting']
# card compound NOUN sorting [] []
# sorting pobj NOUN of ['card'] ['and', 'wiring']
# and cc CCONJ sorting [] []
# board compound NOUN wiring [] []
# wiring conj NOUN sorting ['board'] []
# , punct PUNCT jobs [] []
# all nsubjpass DET considered [] ['of']
# of prep ADP all [] ['which']
# which pobj DET of [] []
# were auxpass VERB considered [] []
# considered relcl VERB jobs ['all', 'were'] ['work']
# women poss NOUN work [] ["'s"]
# 's case PART women [] []
# work oprd NOUN considered ['women'] []
# , punct PUNCT said [] []
# she nsubj PRON said [] []
# said ROOT VERB said ['learned', ',', 'she'] ['.']
# . punct PUNCT said [] []
# [('she', 'learned', 'jobs'), ('jobs', 'considered', 'work')]
# --------------------------------------------------
# sentence: 14
# TV show nailed it
# Fister's classes were filled with other young women, all “dressed like Audrey Hepburn” with high heels and gloves.
# TV compound NOUN show [] []
# show nsubj NOUN nailed ['TV'] []
# nailed ROOT VERB nailed ['show'] ['it']
# it dobj PRON nailed [] ['\n']
#
#   SPACE it [] []
# Fister poss PROPN classes [] ["'s"]
# 's case PART Fister [] []
# classes nsubjpass NOUN filled ['Fister'] ['all']
# were auxpass VERB filled [] []
# filled ROOT VERB filled ['classes', 'were'] ['with', ',', '.']
# with prep ADP filled [] ['women']
# other amod ADJ women [] []
# young amod ADJ women [] []
# women pobj NOUN with ['other', 'young'] []
# , punct PUNCT filled [] []
# all appos DET classes [] ['dressed']
# “ punct NOUN dressed [] []
# dressed acl ADJ all ['“'] ['like', 'with']
# like prep ADP dressed [] ['Hepburn']
# Audrey compound PROPN Hepburn [] []
# Hepburn pobj PROPN like ['Audrey'] ['”']
# ” punct PUNCT Hepburn [] []
# with prep ADP dressed [] ['heels']
# high amod ADJ heels [] []
# heels pobj NOUN with ['high'] ['and', 'gloves']
# and cc CCONJ heels [] []
# gloves conj NOUN heels [] []
# . punct PUNCT filled [] []
# [('show', 'nailed', 'it')]
# --------------------------------------------------
# sentence: 15
# “Did you ever watch 'Mad Men?'
# “ ROOT PROPN “ [] []
# Did aux VERB watch [] []
# you nsubj PRON watch [] []
# ever advmod ADV watch [] []
# watch ROOT VERB watch ['Did', 'you', 'ever'] ["'", 'Men', '?', "'"]
# ' punct PUNCT watch [] []
# Mad compound ADJ Men [] []
# Men npadvmod NOUN watch ['Mad'] []
# ? punct PUNCT watch [] []
# ' punct PUNCT watch [] []
# []
# --------------------------------------------------
# sentence: 16
# ” she asked.
# ” punct PUNCT asked [] []
# she nsubj PRON asked [] []
# asked ROOT VERB asked ['”', 'she'] ['.']
# . punct PUNCT asked [] []
# []
# --------------------------------------------------
# sentence: 17
# “That's exactly how it was.”
# “Mad Men,” an American period television drama, gave an accurate depiction of the professional workplace in the 1960s, she said, right down to the afternoon office cocktails.
# “ ROOT PUNCT “ [] []
# That nsubj DET 's [] []
# 's ROOT VERB 's ['That'] ['was', '.']
# exactly advmod ADV how [] []
# how advmod ADV was ['exactly'] []
# it nsubj PRON was [] []
# was ccomp VERB 's ['how', 'it'] []
# . punct PUNCT 's [] []
# ” ROOT PUNCT ” [] ['\n']
#
#   SPACE ” [] []
# “ ROOT NOUN “ [] []
# Mad amod ADJ Men [] []
# Men nsubj NOUN gave ['Mad'] [',', '”', 'drama']
# , punct PUNCT Men [] []
# ” punct PUNCT Men [] []
# an det DET drama [] []
# American amod ADJ period [] []
# period compound NOUN drama ['American'] []
# television compound NOUN drama [] []
# drama appos NOUN Men ['an', 'period', 'television'] []
# , punct PUNCT gave [] []
# gave ROOT VERB gave ['Men', ','] ['depiction', 'in', 'said', 'down', '.']
# an det DET depiction [] []
# accurate amod ADJ depiction [] []
# depiction dobj NOUN gave ['an', 'accurate'] ['of']
# of prep ADP depiction [] ['workplace']
# the det DET workplace [] []
# professional amod ADJ workplace [] []
# workplace pobj NOUN of ['the', 'professional'] []
# in prep ADP gave [] ['1960s']
# the det DET 1960s [] []
# 1960s pobj NOUN in ['the'] []
# , punct PUNCT said [] []
# she nsubj PRON said [] []
# said parataxis VERB gave [',', 'she'] [',']
# , punct PUNCT said [] []
# right advmod ADV down [] []
# down prep ADV gave ['right'] ['to']
# to prep ADP down [] ['cocktails']
# the det DET cocktails [] []
# afternoon compound NOUN cocktails [] []
# office compound NOUN cocktails [] []
# cocktails pobj NOUN to ['the', 'afternoon', 'office'] []
# . punct PUNCT gave [] []
# [('men', 'gave', 'depiction')]
# --------------------------------------------------
# sentence: 18
# There was sexism in the workplace, too, she said, particularly in the amount women were paid and the jobs available to them.
# There expl ADV was [] []
# was ROOT VERB was ['There'] ['sexism', ',', 'too', 'said', '.']
# sexism attr NOUN was [] ['in']
# in prep ADP sexism [] ['workplace']
# the det DET workplace [] []
# workplace pobj NOUN in ['the'] []
# , punct PUNCT was [] []
# too advmod ADV was [] []
# , punct PUNCT said [] []
# she nsubj PRON said [] []
# said parataxis VERB was [',', 'she'] [',', 'in']
# , punct PUNCT said [] []
# particularly advmod ADV in [] []
# in prep ADP said ['particularly'] ['amount']
# the det DET amount [] []
# amount pobj NOUN in ['the'] ['paid', 'jobs']
# women nsubjpass NOUN paid [] []
# were auxpass VERB paid [] []
# paid relcl VERB amount ['women', 'were'] ['and']
# and cc CCONJ paid [] []
# the det DET jobs [] []
# jobs conj NOUN amount ['the'] ['available']
# available amod ADJ jobs [] ['to']
# to prep ADP available [] ['them']
# them pobj PRON to [] []
# . punct PUNCT was [] []
# [('there', 'was', 'sexism')]
# --------------------------------------------------
# sentence: 19
# Fister worked in the “clean room,” a temperature controlled laboratory where floor-to-ceiling computers stored data on reel-to-reel magnetic tapes.
# Fister nsubj PROPN worked [] []
# worked ROOT VERB worked ['Fister'] ['in', ',', '”', 'laboratory', '.']
# in prep ADP worked [] ['room']
# the det DET room [] []
# “ nmod PROPN room [] []
# clean amod ADJ room [] []
# room pobj NOUN in ['the', '“', 'clean'] []
# , punct PUNCT worked [] []
# ” punct PUNCT worked [] []
# a det DET laboratory [] []
# temperature npadvmod NOUN controlled [] []
# controlled amod VERB laboratory ['temperature'] []
# laboratory dobj NOUN worked ['a', 'controlled'] ['stored']
# where advmod ADV stored [] []
# floor nmod NOUN computers [] ['-', 'to']
# - punct PUNCT floor [] []
# to prep ADP floor [] ['-', 'ceiling']
# - punct PUNCT to [] []
# ceiling pobj NOUN to [] []
# computers nsubj NOUN stored ['floor'] []
# stored relcl VERB laboratory ['where', 'computers'] ['data']
# data dobj NOUN stored [] ['on']
# on prep ADP data [] ['tapes']
# reel nmod NOUN tapes [] ['-', 'to']
# - punct PUNCT reel [] []
# to prep ADP reel [] ['-', 'reel']
# - punct PUNCT to [] []
# reel pobj ADJ to [] []
# magnetic amod ADJ tapes [] []
# tapes pobj NOUN on ['reel', 'magnetic'] []
# . punct PUNCT worked [] []
# [('fister', 'worked', 'laboratory'), ('computers', 'stored', 'data')]
# --------------------------------------------------
# sentence: 20
# Bored by sorting the punched cards, she began studying the repetitive patterns of ones and zeroes in the code.
# Bored advcl VERB began [] ['by']
# by prep ADP Bored [] ['sorting']
# sorting pcomp VERB by [] ['cards']
# the det DET cards [] []
# punched amod VERB cards [] []
# cards dobj NOUN sorting ['the', 'punched'] []
# , punct PUNCT began [] []
# she nsubj PRON began [] []
# began ROOT VERB began ['Bored', ',', 'she'] ['studying', '.']
# studying xcomp VERB began [] ['patterns', 'in']
# the det DET patterns [] []
# repetitive amod ADJ patterns [] []
# patterns dobj NOUN studying ['the', 'repetitive'] ['of']
# of prep ADP patterns [] ['ones']
# ones pobj NOUN of [] ['and', 'zeroes']
# and cc CCONJ ones [] []
# zeroes conj NOUN ones [] []
# in prep ADP studying [] ['code']
# the det DET code [] []
# code pobj NOUN in ['the'] []
# . punct PUNCT began [] []
# [('she', 'studying', 'patterns')]
# --------------------------------------------------
# sentence: 21
# There were some mistakes, she realized, flagging those cards.
# There expl ADV were [] []
# were ccomp VERB realized ['There'] ['mistakes']
# some det DET mistakes [] []
# mistakes attr NOUN were ['some'] []
# , punct PUNCT realized [] []
# she nsubj PRON realized [] []
# realized ROOT VERB realized ['were', ',', 'she'] [',', 'flagging', '.']
# , punct PUNCT realized [] []
# flagging advcl VERB realized [] ['cards']
# those det DET cards [] []
# cards dobj NOUN flagging ['those'] []
# . punct PUNCT realized [] []
# [('there', 'were', 'mistakes')]
# --------------------------------------------------
# sentence: 22
# When one of the coders, as the programmers were called, questioned Fister about “her errors,” she told him: “These are not my mistakes.
# When advmod ADV questioned [] []
# one nsubj NUM questioned [] ['of', ',', 'called']
# of prep ADP one [] ['coders']
# the det DET coders [] []
# coders pobj NOUN of ['the'] []
# , punct PUNCT one [] []
# as mark ADP called [] []
# the det DET programmers [] []
# programmers nsubjpass NOUN called ['the'] []
# were auxpass VERB called [] []
# called advcl VERB one ['as', 'programmers', 'were'] []
# , punct PUNCT questioned [] []
# questioned advcl VERB told ['When', 'one', ','] ['Fister', 'about']
# Fister dobj PROPN questioned [] []
# about prep ADP questioned [] ['errors']
# “ nummod PROPN errors [] []
# her poss DET errors [] []
# errors pobj NOUN about ['“', 'her'] []
# , punct PUNCT told [] []
# ” punct PUNCT told [] []
# she nsubj PRON told [] []
# told ROOT VERB told ['questioned', ',', '”', 'she'] ['him', ':']
# him dobj PRON told [] []
# : punct PUNCT told [] []
# “ ROOT PUNCT “ [] []
# These nsubj DET are [] []
# are ROOT VERB are ['These'] ['not', 'mistakes', '.']
# not neg ADV are [] []
# my poss DET mistakes [] []
# mistakes attr NOUN are ['my'] []
# . punct PUNCT are [] []
# [('one', 'questioned', 'fister'), ('she', 'told', 'him')]
# --------------------------------------------------
# sentence: 23
# They are yours.”
# And she proved it, earning herself a seat in IBM's next programming class.
# They nsubj PRON are [] []
# are ROOT VERB are ['They'] ['yours', '.']
# yours attr DET are [] []
# . punct PUNCT are [] []
# ” ROOT PUNCT ” [] ['\n']
#
#   SPACE ” [] []
# And cc CCONJ proved [] []
# she nsubj PRON proved [] []
# proved ROOT VERB proved ['And', 'she'] ['it', ',', 'earning', '.']
# it dobj PRON proved [] []
# , punct PUNCT proved [] []
# earning advcl VERB proved [] ['herself', 'seat']
# herself dative PRON earning [] []
# a det DET seat [] []
# seat dobj NOUN earning ['a'] ['in']
# in prep ADP seat [] ['class']
# IBM poss PROPN class [] ["'s"]
# 's case PART IBM [] []
# next amod ADJ class [] []
# programming compound NOUN class [] []
# class pobj NOUN in ['IBM', 'next', 'programming'] []
# . punct PUNCT proved [] []
# [('they', 'are', 'yours'), ('she', 'proved', 'it')]
# --------------------------------------------------
# sentence: 24
# Fister was the only woman in her coding course, unlike in her earlier classes.
# Fister nsubj PROPN was [] []
# was ROOT VERB was ['Fister'] ['woman', ',', 'unlike', '.']
# the det DET woman [] []
# only amod ADJ woman [] []
# woman attr NOUN was ['the', 'only'] ['in']
# in prep ADP woman [] ['course']
# her poss DET course [] []
# coding amod NOUN course [] []
# course pobj NOUN in ['her', 'coding'] []
# , punct PUNCT was [] []
# unlike prep ADP was [] ['in']
# in prep ADP unlike [] ['classes']
# her poss DET classes [] []
# earlier amod ADJ classes [] []
# classes pobj NOUN in ['her', 'earlier'] []
# . punct PUNCT was [] []
# [('fister', 'was', 'woman')]
# --------------------------------------------------
# sentence: 25
# “I was uncomfortable and felt out of place,” she said.
# “ ROOT PUNCT “ [] []
# I nsubj PRON was [] []
# was ccomp VERB said ['I'] ['uncomfortable', 'and', 'felt']
# uncomfortable acomp ADJ was [] []
# and cc CCONJ was [] []
# felt conj VERB was [] ['out']
# out prep ADP felt [] ['of']
# of prep ADP out [] ['place']
# place pobj NOUN of [] []
# , punct PUNCT said [] []
# ” punct PUNCT said [] []
# she nsubj PRON said [] []
# said ROOT VERB said ['was', ',', '”', 'she'] ['.']
# . punct PUNCT said [] []
# []
# --------------------------------------------------
# sentence: 26
# “But I was always professional.
# “ ROOT PUNCT “ [] []
# But cc CCONJ was [] []
# I nsubj PRON was [] []
# was ROOT VERB was ['But', 'I'] ['always', 'professional', '.']
# always advmod ADV was [] []
# professional acomp ADJ was [] []
# . punct PUNCT was [] []
# []
# --------------------------------------------------
# sentence: 27
# No flirtation.”
# Some of her male counterparts were skeptical, but she earned their respect by keeping up to pace in Formula Translation, better known as Fortran, and RPG, an IBM proprietary language for business applications.
# No det DET flirtation [] []
# flirtation ROOT NOUN flirtation ['No'] ['.', '”', 'were']
# . punct PUNCT flirtation [] []
# ” punct PUNCT flirtation [] ['\n']
#
#   SPACE ” [] []
# Some nsubj DET were [] ['of']
# of prep ADP Some [] ['counterparts']
# her poss DET counterparts [] []
# male amod ADJ counterparts [] []
# counterparts pobj NOUN of ['her', 'male'] []
# were acl VERB flirtation ['Some'] ['skeptical', ',', 'but', 'earned']
# skeptical acomp ADJ were [] []
# , punct PUNCT were [] []
# but cc CCONJ were [] []
# she nsubj PRON earned [] []
# earned conj VERB were ['she'] ['respect', 'by', '.']
# their poss DET respect [] []
# respect dobj NOUN earned ['their'] []
# by prep ADP earned [] ['keeping']
# keeping pcomp VERB by [] ['up', 'to', 'in']
# up prt PART keeping [] []
# to prep ADP keeping [] ['pace']
# pace pobj NOUN to [] []
# in prep ADP keeping [] ['Translation']
# Formula compound PROPN Translation [] []
# Translation pobj PROPN in ['Formula'] [',', 'known']
# , punct PUNCT Translation [] []
# better advmod ADV known [] []
# known acl VERB Translation ['better'] ['as']
# as prep ADP known [] ['Fortran']
# Fortran pobj PROPN as [] [',', 'and', 'RPG']
# , punct PUNCT Fortran [] []
# and cc CCONJ Fortran [] []
# RPG conj PROPN Fortran [] [',', 'language']
# , punct PUNCT RPG [] []
# an det DET language [] []
# IBM nmod PROPN language [] []
# proprietary amod ADJ language [] []
# language appos NOUN RPG ['an', 'IBM', 'proprietary'] ['for']
# for prep ADP language [] ['applications']
# business compound NOUN applications [] []
# applications pobj NOUN for ['business'] []
# . punct PUNCT earned [] []
# [('she', 'earned', 'respect')]
# --------------------------------------------------
# sentence: 28
# Programming requires an analytical mind, Fister said, and she had that.
# Programming nsubj NOUN requires [] []
# requires ROOT VERB requires ['Programming'] ['mind', 'said', 'and', 'had']
# an det DET mind [] []
# analytical amod ADJ mind [] []
# mind dobj NOUN requires ['an', 'analytical'] []
# , punct PUNCT said [] []
# Fister nsubj PROPN said [] []
# said parataxis VERB requires [',', 'Fister'] [',']
# , punct PUNCT said [] []
# and cc CCONJ requires [] []
# she nsubj PRON had [] []
# had conj VERB requires ['she'] ['that', '.']
# that dobj DET had [] []
# . punct PUNCT had [] []
# [('programming', 'requires', 'mind'), ('she', 'had', 'that')]
# --------------------------------------------------
# sentence: 29
# “I still analyze everything,” she said.
# “ ROOT PUNCT “ [] []
# I nsubj PRON analyze [] []
# still advmod ADV analyze [] []
# analyze ccomp VERB said ['I', 'still'] ['everything']
# everything dobj NOUN analyze [] []
# , punct PUNCT said [] []
# ” punct PUNCT said [] []
# she nsubj PRON said [] []
# said ROOT VERB said ['analyze', ',', '”', 'she'] ['.']
# . punct PUNCT said [] []
# [('i', 'analyze', 'everything')]
# --------------------------------------------------
# sentence: 30
# About a year into her training, the coder she corrected took a job at another company and asked her to work for him.
# About advmod ADV a [] []
# a nummod DET year ['About'] []
# year npadvmod NOUN took ['a'] ['into']
# into prep ADP year [] ['training']
# her poss DET training [] []
# training pobj NOUN into ['her'] []
# , punct PUNCT took [] []
# the det DET coder [] []
# coder nsubj NOUN took ['the'] ['corrected']
# she nsubj PRON corrected [] []
# corrected relcl VERB coder ['she'] []
# took ROOT VERB took ['year', ',', 'coder'] ['job', 'at', 'and', 'asked', '.']
# a det DET job [] []
# job dobj NOUN took ['a'] []
# at prep ADP took [] ['company']
# another det DET company [] []
# company pobj NOUN at ['another'] []
# and cc CCONJ took [] []
# asked conj VERB took [] ['her', 'work']
# her dobj PRON asked [] []
# to aux PART work [] []
# work xcomp VERB asked ['to'] ['for']
# for prep ADP work [] ['him']
# him pobj PRON for [] []
# . punct PUNCT took [] []
# [('coder', 'took', 'job')]
# --------------------------------------------------
# sentence: 31
# Fister embarked on a new adventure but continued taking classes at IBM.
# Fister nsubj PROPN embarked [] []
# embarked ROOT VERB embarked ['Fister'] ['on', 'but', 'continued', '.']
# on prep ADP embarked [] ['adventure']
# a det DET adventure [] []
# new amod ADJ adventure [] []
# adventure pobj NOUN on ['a', 'new'] []
# but cc CCONJ embarked [] []
# continued conj VERB embarked [] ['taking']
# taking xcomp VERB continued [] ['classes', 'at']
# classes dobj NOUN taking [] []
# at prep ADP taking [] ['IBM']
# IBM pobj PROPN at [] []
# . punct PUNCT embarked [] []
# []
# --------------------------------------------------
# sentence: 32
# No glamour
# There were times her boss would call after midnight.
# No det DET glamour [] []
# glamour ROOT NOUN glamour ['No'] ['\n']
#
#   SPACE glamour [] []
# There expl ADV were [] []
# were ROOT VERB were ['There'] ['times', '.']
# times attr NOUN were [] ['call']
# her poss DET boss [] []
# boss nsubj NOUN call ['her'] []
# would aux VERB call [] []
# call relcl VERB times ['boss', 'would'] ['after']
# after prep ADP call [] ['midnight']
# midnight pobj NOUN after [] []
# . punct PUNCT were [] []
# [('there', 'were', 'times')]
# --------------------------------------------------
# sentence: 33
# “Get ready,” he would say.
# “ ROOT PROPN “ [] []
# Get ccomp VERB say [] ['ready']
# ready acomp ADJ Get [] []
# , punct PUNCT say [] []
# ” punct PUNCT say [] []
# he nsubj PRON say [] []
# would aux VERB say [] []
# say ROOT VERB say ['Get', ',', '”', 'he', 'would'] ['.']
# . punct PUNCT say [] []
# []
# --------------------------------------------------
# sentence: 34
# “We have run time.”
# A taxi would arrive to pick her up, and she would be ready and waiting, dressed in her heels with her white gloves on.
# “ ROOT PUNCT “ [] []
# We nsubj PRON run [] []
# have aux VERB run [] []
# run ROOT VERB run ['We', 'have'] ['time', '.']
# time dobj NOUN run [] []
# . punct PUNCT run [] []
# ” ROOT PUNCT ” [] ['\n']
#
#   SPACE ” [] []
# A det DET taxi [] []
# taxi nsubj NOUN arrive ['A'] []
# would aux VERB arrive [] []
# arrive ROOT VERB arrive ['taxi', 'would'] ['pick', ',', 'and', 'be']
# to aux PART pick [] []
# pick xcomp VERB arrive ['to'] ['her', 'up']
# her dobj PRON pick [] []
# up prt PART pick [] []
# , punct PUNCT arrive [] []
# and cc CCONJ arrive [] []
# she nsubj PRON be [] []
# would aux VERB be [] []
# be conj VERB arrive ['she', 'would'] ['ready', ',', 'dressed', '.']
# ready acomp ADJ be [] ['and', 'waiting']
# and cc CCONJ ready [] []
# waiting conj VERB ready [] []
# , punct PUNCT be [] []
# dressed advcl VERB be [] ['in']
# in prep ADP dressed [] ['heels']
# her poss DET heels [] []
# heels pobj NOUN in ['her'] ['with']
# with prep ADP heels [] ['gloves']
# her poss DET gloves [] []
# white amod ADJ gloves [] []
# gloves pobj NOUN with ['her', 'white'] ['on']
# on prep PART gloves [] []
# . punct PUNCT be [] []
# [('we', 'run', 'time'), ('taxi', 'pick', 'her')]
# --------------------------------------------------
# sentence: 35
# After running programs through the night without sleep, they were expected to begin as usual in the morning.
# After prep ADP expected [] ['running']
# running pcomp VERB After [] ['programs', 'through', 'without']
# programs dobj NOUN running [] []
# through prep ADP running [] ['night']
# the det DET night [] []
# night pobj NOUN through ['the'] []
# without prep ADP running [] ['sleep']
# sleep pobj NOUN without [] []
# , punct PUNCT expected [] []
# they nsubjpass PRON expected [] []
# were auxpass VERB expected [] []
# expected ROOT VERB expected ['After', ',', 'they', 'were'] ['begin', '.']
# to aux PART begin [] []
# begin xcomp VERB expected ['to'] ['as', 'in']
# as prep ADV begin [] ['usual']
# usual amod ADJ as [] []
# in prep ADP begin [] ['morning']
# the det DET morning [] []
# morning pobj NOUN in ['the'] []
# . punct PUNCT expected [] []
# []
# --------------------------------------------------
# sentence: 36
# “Everyone thinks it was so glamorous,” she said.
# “ ROOT PROPN “ [] []
# Everyone nsubj NOUN thinks [] []
# thinks ccomp VERB said ['Everyone'] ['was']
# it nsubj PRON was [] []
# was ccomp VERB thinks ['it'] ['glamorous']
# so advmod ADV glamorous [] []
# glamorous acomp ADJ was ['so'] []
# , punct PUNCT said [] []
# ” punct PUNCT said [] []
# she nsubj PRON said [] []
# said ROOT VERB said ['thinks', ',', '”', 'she'] ['.']
# . punct PUNCT said [] []
# []
# --------------------------------------------------
# sentence: 37
# “It wasn't.
# “ ROOT PROPN “ [] []
# It nsubj PRON was [] []
# was ROOT VERB was ['It'] ["n't", '.']
# n't neg ADV was [] []
# . punct PUNCT was [] []
# []
# --------------------------------------------------
# sentence: 38
# It was just work.”
# Women in the 1960s were expected to marry and have children, Fister said, noting many of her friends married right after high school.
# It nsubj PRON was [] []
# was ROOT VERB was ['It'] ['work', '.']
# just advmod ADV work [] []
# work attr NOUN was ['just'] []
# . punct PUNCT was [] []
# ” punct PUNCT expected [] ['\n']
#
#   SPACE ” [] []
# Women nsubjpass NOUN expected [] ['in']
# in prep ADP Women [] ['1960s']
# the det DET 1960s [] []
# 1960s pobj NOUN in ['the'] []
# were auxpass VERB expected [] []
# expected ccomp VERB said ['”', 'Women', 'were'] ['marry']
# to aux PART marry [] []
# marry xcomp VERB expected ['to'] ['and', 'have']
# and cc CCONJ marry [] []
# have conj VERB marry [] ['children']
# children dobj NOUN have [] []
# , punct PUNCT said [] []
# Fister nsubj PROPN said [] []
# said ROOT VERB said ['expected', ',', 'Fister'] [',', 'noting', '.']
# , punct PUNCT said [] []
# noting advcl VERB said [] ['married']
# many nsubj ADJ married [] ['of']
# of prep ADP many [] ['friends']
# her poss DET friends [] []
# friends pobj NOUN of ['her'] []
# married ccomp VERB noting ['many'] ['after']
# right advmod ADV after [] []
# after prep ADP married ['right'] ['school']
# high amod ADJ school [] []
# school pobj NOUN after ['high'] []
# . punct PUNCT said [] []
# [('it', 'was', 'work')]
# --------------------------------------------------
# sentence: 39
# “I wanted that, too,” she said.
# “ ROOT PUNCT “ [] []
# I nsubj PRON wanted [] []
# wanted ccomp VERB said ['I'] []
# that mark ADP said [] []
# , punct PUNCT said [] []
# too advmod ADV said [] []
# , punct PUNCT said [] []
# ” punct PUNCT said [] []
# she nsubj PRON said [] []
# said ROOT VERB said ['wanted', 'that', ',', 'too', ',', '”', 'she'] ['.']
# . punct PUNCT said [] []
# []
# --------------------------------------------------
# sentence: 40
# “I wanted children and a life outside the city.”
# After three years in programming, Fister married and moved with her new husband to his native Berks County.
# “ ROOT PUNCT “ [] []
# I nsubj PRON wanted [] []
# wanted ROOT VERB wanted ['I'] ['children', '.']
# children dobj NOUN wanted [] ['and', 'life']
# and cc CCONJ children [] []
# a det DET life [] []
# life conj NOUN children ['a'] ['outside']
# outside prep ADP life [] ['city']
# the det DET city [] []
# city pobj NOUN outside ['the'] []
# . punct PUNCT wanted [] []
# ” ROOT PUNCT ” [] ['\n']
#
#   SPACE ” [] []
# After prep ADP married [] ['years']
# three nummod NUM years [] []
# years pobj NOUN After ['three'] ['in']
# in prep ADP years [] ['programming']
# programming pobj NOUN in [] []
# , punct PUNCT married [] []
# Fister nsubj PROPN married [] []
# married ROOT VERB married ['After', ',', 'Fister'] ['and', 'moved', '.']
# and cc CCONJ married [] []
# moved conj VERB married [] ['with', 'to']
# with prep ADP moved [] ['husband']
# her poss DET husband [] []
# new amod ADJ husband [] []
# husband pobj NOUN with ['her', 'new'] []
# to prep ADP moved [] ['County']
# his poss DET County [] []
# native amod ADJ County [] []
# Berks compound PROPN County [] []
# County pobj PROPN to ['his', 'native', 'Berks'] []
# . punct PUNCT married [] []
# [('i', 'wanted', 'children'), ('i', 'wanted', 'life')]
# --------------------------------------------------
# sentence: 41
# She was happy as a stay-at-home mother, rearing their two daughters.
# She nsubj PRON was [] []
# was ROOT VERB was ['She'] ['happy', ',', 'rearing', '.']
# happy acomp ADJ was [] ['as']
# as prep ADP happy [] ['mother']
# a det DET mother [] []
# stay nmod NOUN mother [] ['-', 'at']
# - punct PUNCT stay [] []
# at prep ADP stay [] ['-', 'home']
# - punct PUNCT at [] []
# home pobj NOUN at [] []
# mother pobj NOUN as ['a', 'stay'] []
# , punct PUNCT was [] []
# rearing advcl VERB was [] ['daughters']
# their poss DET daughters [] []
# two nummod NUM daughters [] []
# daughters dobj NOUN rearing ['their', 'two'] []
# . punct PUNCT was [] []
# []
# --------------------------------------------------
# sentence: 42
# But when the marriage ended, Fister decided to go back to work.
# But cc CCONJ decided [] []
# when advmod ADV ended [] []
# the det DET marriage [] []
# marriage nsubj NOUN ended ['the'] []
# ended advcl VERB decided ['when', 'marriage'] []
# , punct PUNCT decided [] []
# Fister nsubj PROPN decided [] []
# decided ROOT VERB decided ['But', 'ended', ',', 'Fister'] ['go', '.']
# to aux PART go [] []
# go xcomp VERB decided ['to'] ['back']
# back advmod ADV go [] ['to']
# to prep ADP back [] ['work']
# work pobj NOUN to [] []
# . punct PUNCT decided [] []
# []
# --------------------------------------------------
# sentence: 43
# By then, it was 1984 and computers had changed tremendously.
# By prep ADP was [] ['then']
# then pcomp ADV By [] []
# , punct PUNCT was [] []
# it nsubj PRON was [] []
# was ROOT VERB was ['By', ',', 'it'] ['1984', 'and', 'changed']
# 1984 attr NUM was [] []
# and cc CCONJ was [] []
# computers nsubj NOUN changed [] []
# had aux VERB changed [] []
# changed conj VERB was ['computers', 'had'] ['tremendously', '.']
# tremendously advmod ADV changed [] []
# . punct PUNCT changed [] []
# [('it', 'was', '1984')]
# --------------------------------------------------
# sentence: 44
# She enrolled in a computer programming course offered by an Allentown-area business school.
# She nsubj PRON enrolled [] []
# enrolled ROOT VERB enrolled ['She'] ['in', '.']
# in prep ADP enrolled [] ['course']
# a det DET course [] []
# computer compound NOUN programming [] []
# programming compound NOUN course ['computer'] []
# course pobj NOUN in ['a', 'programming'] ['offered']
# offered acl VERB course [] ['by']
# by agent ADP offered [] ['school']
# an det DET school [] []
# Allentown compound PROPN area [] []
# - punct PUNCT area [] []
# area compound NOUN school ['Allentown', '-'] []
# business compound NOUN school [] []
# school pobj NOUN by ['an', 'area', 'business'] []
# . punct PUNCT enrolled [] []
# []
# --------------------------------------------------
# sentence: 45
# Though the computers were different, she said, one thing was the same: Fister was the only woman in the class.
# Though mark ADP were [] []
# the det DET computers [] []
# computers nsubj NOUN were ['the'] []
# were advcl VERB was ['Though', 'computers'] ['different']
# different acomp ADJ were [] []
# , punct PUNCT said [] []
# she nsubj PRON said [] []
# said parataxis VERB was [',', 'she'] [',']
# , punct PUNCT said [] []
# one nummod NUM thing [] []
# thing nsubj NOUN was ['one'] []
# was ccomp VERB was ['were', 'said', 'thing'] ['same']
# the det DET same [] []
# same attr ADJ was ['the'] []
# : punct PUNCT was [] []
# Fister nsubj PROPN was [] []
# was ROOT VERB was ['was', ':', 'Fister'] ['woman', '.']
# the det DET woman [] []
# only amod ADJ woman [] []
# woman attr NOUN was ['the', 'only'] ['in']
# in prep ADP woman [] ['class']
# the det DET class [] []
# class pobj NOUN in ['the'] []
# . punct PUNCT was [] []
# [('thing', 'was', 'same'), ('fister', 'was', 'woman')]
# --------------------------------------------------
# sentence: 46
# She was studying newer computer languages — Beginner's All-purpose Symbolic Instruction Code, or BASIC, and Common Business-Oriented Language, or COBOL — when her mother fell ill and died three months later.
# She nsubj PRON studying [] []
# was aux VERB studying [] []
# studying ROOT VERB studying ['She', 'was'] ['languages']
# newer amod ADJ languages [] []
# computer compound NOUN languages [] []
# languages dobj NOUN studying ['newer', 'computer'] []
# — ROOT PUNCT — [] []
# Beginner poss PROPN Code [] ["'s"]
# 's case PART Beginner [] []
# All det DET purpose [] []
# - punct PUNCT purpose [] []
# purpose compound NOUN Code ['All', '-'] []
# Symbolic compound PROPN Instruction [] []
# Instruction compound PROPN Code ['Symbolic'] []
# Code ROOT PROPN Code ['Beginner', 'purpose', 'Instruction'] [',', 'or', 'BASIC', 'and', 'Language']
# , punct PUNCT Code [] []
# or cc CCONJ Code [] []
# BASIC conj PROPN Code [] [',']
# , punct PUNCT BASIC [] []
# and cc CCONJ Code [] []
# Common compound PROPN Language [] []
# Business npadvmod PROPN Oriented [] []
# - punct PUNCT Oriented [] []
# Oriented amod VERB Language ['Business', '-'] []
# Language conj PROPN Code ['Common', 'Oriented'] [',', 'or', '—']
# , punct PUNCT Language [] []
# or cc CCONJ Language [] []
# COBOL compound PROPN — [] []
# — conj PROPN Language ['COBOL'] []
# when advmod ADV fell [] []
# her poss DET mother [] []
# mother nsubj NOUN fell ['her'] []
# fell ROOT VERB fell ['when', 'mother'] ['ill', 'and', 'died', '.']
# ill advmod ADV fell [] []
# and cc CCONJ fell [] []
# died conj VERB fell [] ['later']
# three nummod NUM months [] []
# months npadvmod NOUN later ['three'] []
# later advmod ADV died ['months'] []
# . punct PUNCT fell [] []
# [('she', 'studying', 'languages')]
# --------------------------------------------------
# sentence: 47
# Realizing Fister had been distracted and was in mourning, the instructor arranged for a private tutor and helped her snag a programming job with a Reading-area nonprofit.
# Realizing compound VERB Fister [] []
# Fister nsubjpass PROPN distracted ['Realizing'] []
# had aux VERB distracted [] []
# been auxpass VERB distracted [] []
# distracted ROOT VERB distracted ['Fister', 'had', 'been'] ['and', 'was', 'arranged']
# and cc CCONJ distracted [] []
# was conj VERB distracted [] ['in']
# in prep ADP was [] ['mourning']
# mourning pobj NOUN in [] []
# , punct PUNCT arranged [] []
# the det DET instructor [] []
# instructor nsubj NOUN arranged ['the'] []
# arranged conj VERB distracted [',', 'instructor'] ['for', 'and', 'helped', '.']
# for prep ADP arranged [] ['tutor']
# a det DET tutor [] []
# private amod ADJ tutor [] []
# tutor pobj NOUN for ['a', 'private'] []
# and cc CCONJ arranged [] []
# helped conj VERB arranged [] ['snag']
# her nsubj DET snag [] []
# snag ccomp VERB helped ['her'] ['job']
# a det DET job [] []
# programming compound NOUN job [] []
# job dobj NOUN snag ['a', 'programming'] ['with']
# with prep ADP job [] ['nonprofit']
# a det DET nonprofit [] []
# Reading compound NOUN area [] []
# - punct PUNCT area [] []
# area compound NOUN nonprofit ['Reading', '-'] []
# nonprofit pobj NOUN with ['a', 'area'] []
# . punct PUNCT arranged [] []
# []
# --------------------------------------------------
# sentence: 48
# There was no software specifically for nonprofits at the time, Fister said, so she rewrote business programs to suit their needs.
# There expl ADV was [] []
# was ROOT VERB was ['There'] ['software', 'at', 'said', 'so', 'rewrote']
# no det DET software [] []
# software attr NOUN was ['no'] ['for']
# specifically advmod ADV for [] []
# for prep ADP software ['specifically'] ['nonprofits']
# nonprofits pobj NOUN for [] []
# at prep ADP was [] ['time']
# the det DET time [] []
# time pobj NOUN at ['the'] []
# , punct PUNCT said [] []
# Fister nsubj PROPN said [] []
# said parataxis VERB was [',', 'Fister'] [',']
# , punct PUNCT said [] []
# so cc ADV was [] []
# she nsubj PRON rewrote [] []
# rewrote conj VERB was ['she'] ['programs', 'suit', '.']
# business compound NOUN programs [] []
# programs dobj NOUN rewrote ['business'] []
# to aux PART suit [] []
# suit xcomp VERB rewrote ['to'] ['needs']
# their poss DET needs [] []
# needs dobj NOUN suit ['their'] []
# . punct PUNCT rewrote [] []
# [('there', '!was', 'software'), ('she', 'suit', 'programs'), ('she', 'suit', 'needs')]
# --------------------------------------------------
# sentence: 49
# She also was responsible for data entry and used the programs she wrote for record keeping, payroll, accounting and filing various state and federal reports.
# She nsubj PRON was [] []
# also advmod ADV was [] []
# was ROOT VERB was ['She', 'also'] ['responsible', 'and', 'used', '.']
# responsible acomp ADJ was [] ['for']
# for prep ADP responsible [] ['entry']
# data compound NOUN entry [] []
# entry pobj NOUN for ['data'] []
# and cc CCONJ was [] []
# used conj VERB was [] ['programs']
# the det DET programs [] []
# programs dobj NOUN used ['the'] ['wrote']
# she nsubj PRON wrote [] []
# wrote relcl VERB programs ['she'] ['for']
# for prep ADP wrote [] ['keeping']
# record compound NOUN keeping [] []
# keeping pobj NOUN for ['record'] [',', 'payroll']
# , punct PUNCT keeping [] []
# payroll conj NOUN keeping [] [',', 'accounting']
# , punct PUNCT payroll [] []
# accounting conj NOUN payroll [] ['and', 'filing']
# and cc CCONJ accounting [] []
# filing conj VERB accounting [] ['reports']
# various amod ADJ reports [] []
# state nmod NOUN reports [] ['and', 'federal']
# and cc CCONJ state [] []
# federal conj ADJ state [] []
# reports dobj NOUN filing ['various', 'state'] []
# . punct PUNCT was [] []
# [('accounting', 'filing', 'reports')]
# --------------------------------------------------
# sentence: 50
# Fister said she often wasn't “taken seriously” by management and coworkers, who didn't understand what her work entailed, and she was lonely, working solo in the computer room.
# Fister nsubj PROPN said [] []
# said ROOT VERB said ['Fister'] ['taken', ',', 'and', 'was']
# she nsubj PRON taken [] []
# often advmod ADV taken [] []
# was auxpass VERB taken [] []
# n't neg ADV taken [] []
# “ nsubj PUNCT taken [] []
# taken ccomp VERB said ['she', 'often', 'was', "n't", '“'] ['seriously', '”', 'by', ',', 'understand']
# seriously advmod ADV taken [] []
# ” punct PUNCT taken [] []
# by prep ADP taken [] ['management']
# management pobj NOUN by [] ['and', 'coworkers']
# and cc CCONJ management [] []
# coworkers conj NOUN management [] []
# , punct PUNCT taken [] []
# who nsubj PRON understand [] []
# did aux VERB understand [] []
# n't neg ADV understand [] []
# understand advcl VERB taken ['who', 'did', "n't"] ['entailed']
# what dobj PRON entailed [] []
# her poss DET work [] []
# work nsubj NOUN entailed ['her'] []
# entailed ccomp VERB understand ['what', 'work'] []
# , punct PUNCT said [] []
# and cc CCONJ said [] []
# she nsubj PRON was [] []
# was conj VERB said ['she'] ['lonely', ',', 'working', '.']
# lonely acomp ADJ was [] []
# , punct PUNCT was [] []
# working advcl VERB was [] ['solo']
# solo dobj NOUN working [] ['in']
# in prep ADP solo [] ['room']
# the det DET room [] []
# computer compound NOUN room [] []
# room pobj NOUN in ['the', 'computer'] []
# . punct PUNCT was [] []
# []
# --------------------------------------------------
# sentence: 51
# So, she joined an organization for professional programmers, but once again, she was the only woman in the group.
# So advmod ADV joined [] []
# , punct PUNCT joined [] []
# she nsubj PRON joined [] []
# joined ROOT VERB joined ['So', ',', 'she'] ['organization', ',', 'but', 'was']
# an det DET organization [] []
# organization dobj NOUN joined ['an'] ['for']
# for prep ADP organization [] ['programmers']
# professional amod ADJ programmers [] []
# programmers pobj NOUN for ['professional'] []
# , punct PUNCT joined [] []
# but cc CCONJ joined [] []
# once advmod ADV again [] []
# again advmod ADV was ['once'] []
# , punct PUNCT was [] []
# she nsubj PRON was [] []
# was conj VERB joined ['again', ',', 'she'] ['woman', '.']
# the det DET woman [] []
# only amod ADJ woman [] []
# woman attr NOUN was ['the', 'only'] ['in']
# in prep ADP woman [] ['group']
# the det DET group [] []
# group pobj NOUN in ['the'] []
# . punct PUNCT was [] []
# [('she', 'joined', 'organization'), ('she', 'was', 'woman')]
# --------------------------------------------------
# sentence: 52
# Before her retirement in 1995, she dabbled in Microsoft Windows, the graphical user interface that would revolutionize personal computing.
# Before prep ADP dabbled [] ['retirement']
# her poss DET retirement [] []
# retirement pobj NOUN Before ['her'] ['in']
# in prep ADP retirement [] ['1995']
# 1995 pobj NUM in [] []
# , punct PUNCT dabbled [] []
# she nsubj PRON dabbled [] []
# dabbled ROOT VERB dabbled ['Before', ',', 'she'] ['in', '.']
# in prep ADP dabbled [] ['Windows']
# Microsoft compound PROPN Windows [] []
# Windows pobj PROPN in ['Microsoft'] [',', 'interface']
# , punct PUNCT Windows [] []
# the det DET interface [] []
# graphical amod ADJ interface [] []
# user compound NOUN interface [] []
# interface appos NOUN Windows ['the', 'graphical', 'user'] ['revolutionize']
# that nsubj DET revolutionize [] []
# would aux VERB revolutionize [] []
# revolutionize relcl VERB interface ['that', 'would'] ['computing']
# personal amod ADJ computing [] []
# computing dobj NOUN revolutionize ['personal'] []
# . punct PUNCT dabbled [] []
# [('interface', 'revolutionize', 'computing')]
# --------------------------------------------------
# sentence: 53
# “By then, I had learned six computer languages and was burnt out,” she said.
# “ ROOT PUNCT “ [] []
# By prep ADP learned [] ['then']
# then pcomp ADV By [] []
# , punct PUNCT learned [] []
# I nsubj PRON learned [] []
# had aux VERB learned [] []
# learned ccomp VERB said ['By', ',', 'I', 'had'] ['languages', 'and', 'burnt']
# six nummod NUM languages [] []
# computer compound NOUN languages [] []
# languages dobj NOUN learned ['six', 'computer'] []
# and cc CCONJ learned [] []
# was auxpass VERB burnt [] []
# burnt conj VERB learned ['was'] ['out']
# out prt PART burnt [] []
# , punct PUNCT said [] []
# ” punct PUNCT said [] []
# she nsubj PRON said [] []
# said ROOT VERB said ['learned', ',', '”', 'she'] ['.']
# . punct PUNCT said [] []
# [('i', 'learned', 'languages')]
# --------------------------------------------------
# sentence: 54
# “But the desire to work with computers is still there.
# “ ROOT PUNCT “ [] []
# But cc CCONJ is [] []
# the det DET desire [] []
# desire nsubj NOUN is ['the'] ['work']
# to aux PART work [] []
# work acl VERB desire ['to'] ['with']
# with prep ADP work [] ['computers']
# computers pobj NOUN with [] []
# is ROOT VERB is ['But', 'desire'] ['still', 'there', '.']
# still advmod ADV is [] []
# there advmod ADV is [] []
# . punct PUNCT is [] []
# []
# --------------------------------------------------
# sentence: 55
# It is almost like it is in my DNA.”
# It nsubj PRON is [] []
# is ROOT VERB is ['It'] ['is', '.']
# almost advmod ADV like [] []
# like mark ADP is ['almost'] []
# it nsubj PRON is [] []
# is advcl VERB is ['like', 'it'] ['in']
# in prep ADP is [] ['DNA']
# my poss DET DNA [] []
# DNA pobj NOUN in ['my'] []
# . punct PUNCT is [] []
# ” ROOT PUNCT ” [] []
# []
# --------------------------------------------------
# [[], [('box', 'blinking', 'lights'), ('lights', 'transfixed', 'fister')], [('it', 'was', 'computer')], [('it', 'piqued', 'curiosity')], [], [('it', 'be', 'future')], [('programmer', 'was', 'woman')], [('it', 'be', 'woman')], [], [], [('what', 'called', 'machines'), ('man', 'handed', 'her'), ('man', 'handed', 'card')], [], [('fister', 'received', 'training'), ('cards', 'issued', 'commands')], [('she', 'learned', 'jobs'), ('jobs', 'considered', 'work')], [('show', 'nailed', 'it')], [], [], [('men', 'gave', 'depiction')], [('there', 'was', 'sexism')], [('fister', 'worked', 'laboratory'), ('computers', 'stored', 'data')], [('she', 'studying', 'patterns')], [('there', 'were', 'mistakes')], [('one', 'questioned', 'fister'), ('she', 'told', 'him')], [('they', 'are', 'yours'), ('she', 'proved', 'it')], [('fister', 'was', 'woman')], [], [], [('she', 'earned', 'respect')], [('programming', 'requires', 'mind'), ('she', 'had', 'that')], [('i', 'analyze', 'everything')], [('coder', 'took', 'job')], [], [('there', 'were', 'times')], [], [('we', 'run', 'time'), ('taxi', 'pick', 'her')], [], [], [], [('it', 'was', 'work')], [], [('i', 'wanted', 'children'), ('i', 'wanted', 'life')], [], [], [('it', 'was', '1984')], [], [('thing', 'was', 'same'), ('fister', 'was', 'woman')], [('she', 'studying', 'languages')], [], [('there', '!was', 'software'), ('she', 'suit', 'programs'), ('she', 'suit', 'needs')], [('accounting', 'filing', 'reports')], [], [('she', 'joined', 'organization'), ('she', 'was', 'woman')], [('interface', 'revolutionize', 'computing')], [('i', 'learned', 'languages')], [], []]

# %% [markdown]
# Keyword Extraction using TextRank¶

# %% [markdown]
# # Apply TextRank for ranking and selecting key phrases, print the result ¶

# %%
from collections import OrderedDict
import numpy as np
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
nlp = spacy.load('en_core_web_sm')

# %%
class TextRank4Keyword():
    """Extract keywords from text"""
    
    def __init__(self):
        self.d = 0.85 # damping coefficient, usually is .85
        self.min_diff = 1e-5 # convergence threshold
        self.steps = 10 # iteration steps
        self.node_weight = None # save keywords and its weight

    
    def set_stopwords(self, stopwords):  
        """Set stop words"""
        for word in STOP_WORDS.union(set(stopwords)):
            lexeme = nlp.vocab[word]
            lexeme.is_stop = True
    
    def sentence_segment(self, doc, candidate_pos, lower):
        """Store those words only in cadidate_pos"""
        sentences = []
        for sent in doc.sents:
            selected_words = []
            for token in sent:
                # Store words only with cadidate POS tag
                if token.pos_ in candidate_pos and token.is_stop is False:
                    if lower is True:
                        selected_words.append(token.text.lower())
                    else:
                        selected_words.append(token.text)
            sentences.append(selected_words)
        return sentences
        
    def get_vocab(self, sentences):
        """Get all tokens"""
        vocab = OrderedDict()
        i = 0
        for sentence in sentences:
            for word in sentence:
                if word not in vocab:
                    vocab[word] = i
                    i += 1
        return vocab
    
    def get_token_pairs(self, window_size, sentences):
        """Build token_pairs from windows in sentences"""
        token_pairs = list()
        for sentence in sentences:
            for i, word in enumerate(sentence):
                for j in range(i+1, i+window_size):
                    if j >= len(sentence):
                        break
                    pair = (word, sentence[j])
                    if pair not in token_pairs:
                        token_pairs.append(pair)
        return token_pairs
        
    def symmetrize(self, a):
        return a + a.T - np.diag(a.diagonal())
    
    def get_matrix(self, vocab, token_pairs):
        """Get normalized matrix"""
        # Build matrix
        vocab_size = len(vocab)
        g = np.zeros((vocab_size, vocab_size), dtype='float')
        for word1, word2 in token_pairs:
            i, j = vocab[word1], vocab[word2]
            g[i][j] = 1
            
        # Get Symmeric matrix
        g = self.symmetrize(g)
        
        # Normalize matrix by column
        norm = np.sum(g, axis=0)
        g_norm = np.divide(g, norm, where=norm!=0) # this is ignore the 0 element in norm
        
        return g_norm

    
    def get_keywords(self, number=10):
        """Print top number keywords"""
        node_weight = OrderedDict(sorted(self.node_weight.items(), key=lambda t: t[1], reverse=True))
        for i, (key, value) in enumerate(node_weight.items()):
            print(key + ' - ' + str(value))
            if i > number:
                break
        
        
    def analyze(self, text, 
                candidate_pos=['NOUN', 'PROPN'], 
                window_size=4, lower=False, stopwords=list()):
        """Main function to analyze text"""
        
        # Set stop words
        self.set_stopwords(stopwords)
        
        # Pare text by spaCy
        doc = nlp(text)
        
        # Filter sentences
        sentences = self.sentence_segment(doc, candidate_pos, lower) # list of list of words
        
        # Build vocabulary
        vocab = self.get_vocab(sentences)
        
        # Get token_pairs from windows
        token_pairs = self.get_token_pairs(window_size, sentences)
        
        # Get normalized matrix
        g = self.get_matrix(vocab, token_pairs)
        
        # Initionlization for weight(pagerank value)
        pr = np.array([1] * len(vocab))
        
        # Iteration
        previous_pr = 0
        for epoch in range(self.steps):
            pr = (1-self.d) + self.d * np.dot(g, pr)
            if abs(previous_pr - sum(pr))  < self.min_diff:
                break
            else:
                previous_pr = sum(pr)

        # Get weight for each node
        node_weight = dict()
        for word, index in vocab.items():
            node_weight[word] = pr[index]
        
        self.node_weight = node_weight

# %%
keyphrase_extractor = TextRank4Keyword()

# %%
text = article
tr4w = TextRank4Keyword()
tr4w.analyze(text, candidate_pos = ['NOUN', 'PROPN',"ADP"], window_size=8, lower=False)
tr4w.get_keywords(10)
# Out:
# Fister - 9.352367450402657
# IBM - 2.7370022511680614
# programming - 2.7053541801781584
# computers - 2.51202542223173
# woman - 2.416758038055165
# computer - 2.3263060540011007
# business - 2.2588802354279047
# programs - 2.065942243650789
# work - 2.0410934046362192
# office - 1.9975074422433332
# job - 1.90425240309769
# “ - 1.881877411627169

# %%
#Another TextRank Implementation
def extract_candidate_chunks(text, grammar=r'KT: {(<JJ>* <NN.*>+ <IN>)? <JJ>* <NN.*>+}'):
    import itertools, nltk, string
    
    # exclude candidates that are stop words or entirely punctuation
    punct = set(string.punctuation)
    stop_words = set(nltk.corpus.stopwords.words('english'))
    # tokenize, POS-tag, and chunk using regular expressions
    chunker = nltk.chunk.regexp.RegexpParser(grammar)
    tagged_sents = nltk.pos_tag_sents(nltk.word_tokenize(sent) for sent in nltk.sent_tokenize(text))
    all_chunks = list(itertools.chain.from_iterable(nltk.chunk.tree2conlltags(chunker.parse(tagged_sent)) for tagged_sent in tagged_sents))
    # join constituent chunk words into a single chunked phrase
    candidates = [' '.join(word for word, pos, chunk in group).lower()
                  for key, group in itertools.groupby(all_chunks, lambda word__pos__chunk: word__pos__chunk[2] != 'O') if key]

    return [cand for cand in candidates
            if cand not in stop_words and not all(char in punct for char in cand)]

def extract_candidate_words(text, good_tags=set(['JJ','JJR','JJS','NN','NNP','NNS','NNPS'])):
    import itertools, nltk, string

    # exclude candidates that are stop words or entirely punctuation
    punct = set(string.punctuation)
    stop_words = set(nltk.corpus.stopwords.words('english'))
    # tokenize and POS-tag words
    tagged_words = itertools.chain.from_iterable(nltk.pos_tag_sents(nltk.word_tokenize(sent)
                                                                    for sent in nltk.sent_tokenize(text)))
    # filter on certain POS tags and lowercase all words
    candidates = [word.lower() for word, tag in tagged_words
                  if tag in good_tags and word.lower() not in stop_words
                  and not all(char in punct for char in word)]

    return candidates

def score_keyphrases_by_textrank(text, n_keywords=0.05):
    from itertools import takewhile, tee
    import operator
    import networkx, nltk
    
    # tokenize for all words, and extract *candidate* words
    words = [word.lower()
             for sent in nltk.sent_tokenize(text)
             for word in nltk.word_tokenize(sent)]
    candidates = extract_candidate_words(text)
    # build graph, each node is a unique candidate
    graph = networkx.Graph()
    graph.add_nodes_from(set(candidates))
    # iterate over word-pairs, add unweighted edges into graph
    def pairwise(iterable):
        """s -> (s0,s1), (s1,s2), (s2, s3), ..."""
        a, b = tee(iterable)
        next(b, None)
        return zip(a, b)
    for w1, w2 in pairwise(candidates):
        if w2:
            graph.add_edge(*sorted([w1, w2]))
    # score nodes using default pagerank algorithm, sort by score, keep top n_keywords
    ranks = networkx.pagerank(graph)
    if 0 < n_keywords < 1:
        n_keywords = int(round(len(candidates) * n_keywords))
    word_ranks = {word_rank[0]: word_rank[1]
                  for word_rank in sorted(ranks.items(), key=operator.itemgetter(1), reverse=True)[:n_keywords]}
                  #for word_rank in sorted(ranks.iteritems(), key=lambda x: x[1], reverse=True)[:n_keywords]}
                  
    #sorted(max_value_score.items(), key=operator.itemgetter(1), reverse=True)[:3]
    keywords = set(word_ranks.keys())
    # merge keywords into keyphrases
    keyphrases = {}
    j = 0
    for i, word in enumerate(words):
        if i < j:
            continue
        if word in keywords:
            kp_words = list(takewhile(lambda x: x in keywords, words[i:i+10]))
            avg_pagerank = sum(word_ranks[w] for w in kp_words) / float(len(kp_words))
            keyphrases[' '.join(kp_words)] = avg_pagerank
            # counter as hackish way to ensure merged keyphrases are non-overlapping
            j = i + len(kp_words)
            
    return sorted(keyphrases.items(), key=operator.itemgetter(1), reverse=True)
    #return sorted(keyphrases.iteritems(), key=lambda x: x[1], reverse=True)

# %%
text = article
score_keyphrases_by_textrank(text)
# Out:
# [('fister', 0.04226009650997202),
#  ('“', 0.03283757323170861),
#  ('” “', 0.025509284515899934),
#  ('“ business', 0.021815078758509993),
#  ('”', 0.01818099580009126),
#  ('ibm', 0.015349761152073227),
#  ('computers', 0.014802432156062856),
#  ('” women', 0.014050433546074981),
#  ('computer', 0.013987859102320546),
#  ('computer programming', 0.01138310468369223),
#  ('business', 0.010792584285311376),
#  ('woman', 0.010210241872254482),
#  ('professional', 0.010121011512377294),
#  ('women', 0.009919871292058704),
#  ('business programs', 0.009635760618369203),
#  ('cards', 0.00916311836219137),
#  ('programming', 0.008778350265063913),
#  ('work', 0.008649651998957118),
#  ('programs', 0.00847893695142703),
#  ('programming job', 0.008410484353702749),
#  ('job', 0.008042618442341585),
#  ('office', 0.0076584995888076355),
#  ('classes', 0.007427060164090742),
#  ('code', 0.00650021811716708)]

# %% [markdown]
# # Apply LexRank to produce an extractive summary of 5 sentences.

# %%
#!pip install sumy
# Out:
# Collecting sumy
#   Downloading https://files.pythonhosted.org/packages/61/20/8abf92617ec80a2ebaec8dc1646a790fc9656a4a4377ddb9f0cc90bc9326/sumy-0.8.1-py2.py3-none-any.whl (83kB)
#      |████████████████████████████████| 92kB 2.8MB/s eta 0:00:011
# Collecting docopt<0.7,>=0.6.1 (from sumy)
#   Downloading https://files.pythonhosted.org/packages/a2/55/8f8cab2afd404cf578136ef2cc5dfb50baa1761b68c9da1fb1e4eed343c9/docopt-0.6.2.tar.gz
# Requirement already satisfied: nltk>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from sumy) (3.4.4)
# Collecting pycountry>=18.2.23 (from sumy)
#   Downloading https://files.pythonhosted.org/packages/16/b6/154fe93072051d8ce7bf197690957b6d0ac9a21d51c9a1d05bd7c6fdb16f/pycountry-19.8.18.tar.gz (10.0MB)
#      |████████████████████████████████| 10.0MB 4.8MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.7.0 in /anaconda3/lib/python3.7/site-packages (from sumy) (2.22.0)
# Collecting breadability>=0.1.20 (from sumy)
#   Downloading https://files.pythonhosted.org/packages/ad/2d/bb6c9b381e6b6a432aa2ffa8f4afdb2204f1ff97cfcc0766a5b7683fec43/breadability-0.1.20.tar.gz
# Requirement already satisfied: six in /anaconda3/lib/python3.7/site-packages (from nltk>=3.0.2->sumy) (1.12.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /anaconda3/lib/python3.7/site-packages (from requests>=2.7.0->sumy) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.7/site-packages (from requests>=2.7.0->sumy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.7/site-packages (from requests>=2.7.0->sumy) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.7/site-packages (from requests>=2.7.0->sumy) (3.0.4)
# Requirement already satisfied: lxml>=2.0 in /anaconda3/lib/python3.7/site-packages (from breadability>=0.1.20->sumy) (4.3.4)
# Building wheels for collected packages: docopt, pycountry, breadability
#   Building wheel for docopt (setup.py) ... done
#   Stored in directory: /Users/rissacao/Library/Caches/pip/wheels/9b/04/dd/7daf4150b6d9b12949298737de9431a324d4b797ffd63f526e
#   Building wheel for pycountry (setup.py) ... done
#   Stored in directory: /Users/rissacao/Library/Caches/pip/wheels/a2/98/bf/f0fa1c6bf8cf2cbdb750d583f84be51c2cd8272460b8b36bd3
#   Building wheel for breadability (setup.py) ... done
#   Stored in directory: /Users/rissacao/Library/Caches/pip/wheels/5a/4d/a1/510b12c5e65e0b2b3ce539b2af66da0fc57571e528924f4a52
# Successfully built docopt pycountry breadability
# Installing collected packages: docopt, pycountry, breadability, sumy
# Successfully installed breadability-0.1.20 docopt-0.6.2 pycountry-19.8.18 sumy-0.8.1

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.parsers.html import HtmlParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lex_rank import LexRankSummarizer

class TextSummary(object):

    def __init__(self, feeds_str, num_sents):
        self.summary = str()
        
        parser = PlaintextParser.from_string(feeds_str, Tokenizer("english"))
        summarizer = LexRankSummarizer()

        sentences = summarizer(parser.document, num_sents)  # Summarize the document with 5 sentences
        for sentence in sentences:
            self.summary += (sentence.__unicode__())

    def output(self):
        return self.summary

# %%
input_text = article

# %%
text_to_sum = TextSummary(input_text,5)
print(text_to_sum.output())
# Out:
# A retired computer programmer, Fister, now 75, of Exeter Township was the only woman in her class when she started programming close to 60 years ago.A few years after that decisive museum trip, Fister, who grew up in a suburb of the Windy City, walked into the Chicago office of International Business Machines, or IBM, to ask for a job.“It wasn't.It was just work.” Women in the 1960s were expected to marry and have children, Fister said, noting many of her friends married right after high school.“By then, I had learned six computer languages and was burnt out,” she said.
